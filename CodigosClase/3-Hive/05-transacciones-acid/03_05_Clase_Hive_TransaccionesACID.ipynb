# %%
# %load_ext bigdata

# %%
# %timeout 300

# %%
## Creacion tabla

# %%
# %%hive
# DROP DATABASE IF EXISTS demo CASCADE;
# CREATE DATABASE demo;
# USE demo;
#
# CREATE TABLE persons (
#     id        INT,
#     firstname STRING,
#     surname   STRING,
#     birthday  TIMESTAMP,
#     quantity  INT
# )
# PARTITIONED BY (color STRING)
# CLUSTERED BY(id) INTO 3 BUCKETS
# STORED AS ORC
# LOCATION '/tmp/hive-partitioned'
# TBLPROPERTIES ('transactional'='true');
# Out:
# DROP DATABASE IF EXISTS demo CASCADE;
# OK
# Time taken: 8.977 seconds
# CREATE DATABASE demo;
# OK
# Time taken: 0.598 seconds
# USE demo;
# OK
# Time taken: 0.027 seconds
# CREATE TABLE persons (
#     id        INT,
#     firstname STRING,
#     surname   STRING,
#     birthday  TIMESTAMP,
#     quantity  INT
# )
# PARTITIONED BY (color STRING)
# CLUSTERED BY(id) INTO 3 BUCKETS
# STORED AS ORC
# LOCATION '/tmp/hive-partitioned'
# TBLPROPERTIES ('transactional'='true');
# OK
# Time taken: 0.737 seconds

# %%
## Preparación
##   Se deben habilitar las características de Hive para manejo de transacciones ACID.

# %%
# %%hive
# SET hive.txn.manager=org.apache.hadoop.hive.ql.lockmgr.DbTxnManager;
# SET hive.support.concurrency=true;
# SET hive.enforce.bucketing=true;
# SET hive.exec.dynamic.partition.mode=nonstrict;
# SET hive.compactor.initiator.on=true;
# SET hive.compactor.worker.threads=1;
# Out:
# SET hive.txn.manager=org.apache.hadoop.hive.ql.lockmgr.DbTxnManager;
# SET hive.support.concurrency=true;
# SET hive.enforce.bucketing=true;
# SET hive.exec.dynamic.partition.mode=nonstrict;
# SET hive.compactor.initiator.on=true;
# SET hive.compactor.worker.threads=1;

# %%
## INSERT

##   INSERT INTO TABLE tablename VALUES PARTITION () values_row [, values_row ...]
##    values_row:
##       (value [, value ...])

## Note que a diferencia de SQL, aca no es posible indicar para que columnas se van a insertar los valores, de tal manera que siempre se deben dar valores para todas las columnas.

# %%
# %%hive
# --
# -- Inserta el registro en la tabla.
# -- Los valores están en el mismo orden de los campos.
# --
# INSERT INTO persons PARTITION (color='green') VALUES
#     (1,"Vivian","Hamilton","1971-07-08",1),
#     (2,"Karen","Holcomb","1974-05-23",4),
#     (12,"Hope","Coffey","1973-12-24",5),
#     (17,"Chanda","Boyer","1973-04-01",4);
#
# INSERT INTO persons PARTITION (color='black') VALUES
#     (4,"Roth","Fry","1975-01-29",1),
#     (10,"Kylan","Sexton","1975-02-28",4);
#
# INSERT INTO persons PARTITION (color='blue') VALUES
#     (5,"Zoe","Conway","1974-07-03",2),
#     (7,"Driscoll","Klein","1970-10-05",5),
#     (15,"Hope","Silva","1970-07-01",5);
#
# INSERT INTO persons PARTITION (color='orange') VALUES
#     (3,"Cody","Garrett","1973-04-22",1),
#     (16,"Ayanna","Jarvis","1974-02-11",5);
#
# INSERT INTO persons PARTITION (color='violet') VALUES
#     (6,"Gretchen","Kinney","1974-10-18",1);
#
# INSERT INTO persons PARTITION (color='red') VALUES
#     (8,"Karyn","Diaz","1969-02-24",1),
#     (14,"Clio","Noel","1972-12-12",5);
#
# INSERT INTO persons PARTITION (color='indigo') VALUES
#     (9,"Merritt","Guy","1974-10-17",4),
#     (11,"Jordan","Estes","1969-12-07",4);
#
# INSERT INTO persons PARTITION (color='gray') VALUES
#     (13,"Vivian","Crane","1970-08-27",5);
#
# INSERT INTO persons PARTITION (color='yellow') VALUES
#     (18,"Chadwick","Knight","1973-04-29",1);
# Out:
# --
# -- Inserta el registro en la tabla.
# -- Los valores est??n en el mismo orden de los campos.
# --
# INSERT INTO persons PARTITION (color='green') VALUES
#     (1,"Vivian","Hamilton","1971-07-08",1),
#     (2,"Karen","Holcomb","1974-05-23",4),
#     (12,"Hope","Coffey","1973-12-24",5),
#     (17,"Chanda","Boyer","1973-04-01",4);
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127214320_5f6b574e-c3f0-4583-ac28-80b76d1be1ae
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0017, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0017/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0017
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 3
# 2019-11-27 21:43:36,900 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:43:43,596 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.92 sec
# 2019-11-27 21:43:53,899 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 8.6 sec
# 2019-11-27 21:43:56,075 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 17.24 sec
# MapReduce Total cumulative CPU time: 17 seconds 240 msec
# Ended Job = job_1574885052112_0017
# Loading data to table demo.persons partition (color=green)
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 3   Cumulative CPU: 17.24 sec   HDFS Read: 20555 HDFS Write: 2970 SUCCESS
# Total MapReduce CPU Time Spent: 17 seconds 240 msec
# OK
# Time taken: 38.632 seconds
# INSERT INTO persons PARTITION (color='black') VALUES
#     (4,"Roth","Fry","1975-01-29",1),
#     (10,"Kylan","Sexton","1975-02-28",4);
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127214359_d0c91cc6-bbcf-42a7-93dc-ea759729a401
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0018, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0018/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0018
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 3
# 2019-11-27 21:44:12,488 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:44:19,143 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.07 sec
# 2019-11-27 21:44:28,290 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 7.51 sec
# 2019-11-27 21:44:30,576 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 7.51 sec
# 2019-11-27 21:44:31,691 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 16.32 sec
# MapReduce Total cumulative CPU time: 16 seconds 320 msec
# Ended Job = job_1574885052112_0018
# Loading data to table demo.persons partition (color=black)
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 3   Cumulative CPU: 16.32 sec   HDFS Read: 20566 HDFS Write: 1567 SUCCESS
# Total MapReduce CPU Time Spent: 16 seconds 320 msec
# OK
# Time taken: 35.082 seconds
# INSERT INTO persons PARTITION (color='blue') VALUES
#     (5,"Zoe","Conway","1974-07-03",2),
#     (7,"Driscoll","Klein","1970-10-05",5),
#     (15,"Hope","Silva","1970-07-01",5);
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127214434_3db2cdda-5a9f-4f87-b8d4-3853c5fed446
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0019, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0019/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0019
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 3
# 2019-11-27 21:44:47,459 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:44:55,104 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 2.88 sec
# 2019-11-27 21:45:05,118 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 7.26 sec
# 2019-11-27 21:45:06,192 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 12.1 sec
# 2019-11-27 21:45:07,328 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 16.95 sec
# MapReduce Total cumulative CPU time: 16 seconds 950 msec
# Ended Job = job_1574885052112_0019
# Loading data to table demo.persons partition (color=blue)
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 3   Cumulative CPU: 16.95 sec   HDFS Read: 20581 HDFS Write: 2884 SUCCESS
# Total MapReduce CPU Time Spent: 16 seconds 950 msec
# OK
# Time taken: 35.504 seconds
# INSERT INTO persons PARTITION (color='orange') VALUES
#     (3,"Cody","Garrett","1973-04-22",1),
#     (16,"Ayanna","Jarvis","1974-02-11",5);
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127214510_f4d8aba8-ad27-417c-b04f-a32bb5a721d8
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0020, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0020/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0020
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 3
# 2019-11-27 21:45:22,998 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:45:29,502 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.25 sec
# 2019-11-27 21:45:39,637 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 7.77 sec
# 2019-11-27 21:45:40,703 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 12.49 sec
# 2019-11-27 21:45:41,750 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 16.63 sec
# MapReduce Total cumulative CPU time: 16 seconds 630 msec
# Ended Job = job_1574885052112_0020
# Loading data to table demo.persons partition (color=orange)
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 3   Cumulative CPU: 16.63 sec   HDFS Read: 20586 HDFS Write: 2202 SUCCESS
# Total MapReduce CPU Time Spent: 16 seconds 630 msec
# OK
# Time taken: 32.738 seconds
# INSERT INTO persons PARTITION (color='violet') VALUES
#     (6,"Gretchen","Kinney","1974-10-18",1);
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127214543_1ed0df61-2010-4f69-92f1-fa878074bffc
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0021, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0021/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0021
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 3
# 2019-11-27 21:45:55,900 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:46:02,397 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 2.65 sec
# 2019-11-27 21:46:12,458 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 7.09 sec
# 2019-11-27 21:46:14,650 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 11.4 sec
# 2019-11-27 21:46:15,763 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 15.5 sec
# MapReduce Total cumulative CPU time: 15 seconds 500 msec
# Ended Job = job_1574885052112_0021
# Loading data to table demo.persons partition (color=violet)
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 3   Cumulative CPU: 15.5 sec   HDFS Read: 20559 HDFS Write: 1531 SUCCESS
# Total MapReduce CPU Time Spent: 15 seconds 500 msec
# OK
# Time taken: 34.059 seconds
# INSERT INTO persons PARTITION (color='red') VALUES
#     (8,"Karyn","Diaz","1969-02-24",1),
#     (14,"Clio","Noel","1972-12-12",5);
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127214617_43a48741-3faa-41c9-ad2a-a87238b1c167
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0022, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0022/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0022
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 3
# 2019-11-27 21:46:30,305 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:46:37,993 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.47 sec
# 2019-11-27 21:46:48,061 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 7.2 sec
# 2019-11-27 21:46:49,164 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 11.04 sec
# 2019-11-27 21:46:50,218 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 15.04 sec
# MapReduce Total cumulative CPU time: 15 seconds 40 msec
# Ended Job = job_1574885052112_0022
# Loading data to table demo.persons partition (color=red)
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 3   Cumulative CPU: 15.04 sec   HDFS Read: 20535 HDFS Write: 1570 SUCCESS
# Total MapReduce CPU Time Spent: 15 seconds 40 msec
# OK
# Time taken: 34.037 seconds
# INSERT INTO persons PARTITION (color='indigo') VALUES
#     (9,"Merritt","Guy","1974-10-17",4),
#     (11,"Jordan","Estes","1969-12-07",4);
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127214651_f08f63d7-9e43-43c9-94a2-8959f959440a
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0023, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0023/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0023
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 3
# 2019-11-27 21:47:05,488 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:47:12,052 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.03 sec
# 2019-11-27 21:47:22,118 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 7.07 sec
# 2019-11-27 21:47:23,186 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 11.55 sec
# 2019-11-27 21:47:24,265 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 15.81 sec
# MapReduce Total cumulative CPU time: 15 seconds 810 msec
# Ended Job = job_1574885052112_0023
# Loading data to table demo.persons partition (color=indigo)
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 3   Cumulative CPU: 15.81 sec   HDFS Read: 20584 HDFS Write: 2207 SUCCESS
# Total MapReduce CPU Time Spent: 15 seconds 810 msec
# OK
# Time taken: 35.145 seconds
# INSERT INTO persons PARTITION (color='gray') VALUES
#     (13,"Vivian","Crane","1970-08-27",5);
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127214727_6c7a7583-6997-4972-bee4-001baf63217a
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0024, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0024/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0024
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 3
# 2019-11-27 21:47:39,501 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:47:47,022 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 2.8 sec
# 2019-11-27 21:47:55,843 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 7.09 sec
# 2019-11-27 21:47:58,079 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 15.73 sec
# MapReduce Total cumulative CPU time: 15 seconds 730 msec
# Ended Job = job_1574885052112_0024
# Loading data to table demo.persons partition (color=gray)
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 3   Cumulative CPU: 15.73 sec   HDFS Read: 20527 HDFS Write: 1520 SUCCESS
# Total MapReduce CPU Time Spent: 15 seconds 730 msec
# OK
# Time taken: 32.379 seconds
# INSERT INTO persons PARTITION (color='yellow') VALUES
#     (18,"Chadwick","Knight","1973-04-29",1);
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127214759_32ddb835-f3aa-4701-bd3f-2b1403602491
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0025, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0025/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0025
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 3
# 2019-11-27 21:48:13,205 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:48:19,565 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.07 sec
# 2019-11-27 21:48:29,630 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 7.7 sec
# 2019-11-27 21:48:30,687 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 12.13 sec
# 2019-11-27 21:48:31,811 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 16.52 sec
# MapReduce Total cumulative CPU time: 16 seconds 520 msec
# Ended Job = job_1574885052112_0025
# Loading data to table demo.persons partition (color=yellow)
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 3   Cumulative CPU: 16.52 sec   HDFS Read: 20560 HDFS Write: 1539 SUCCESS
# Total MapReduce CPU Time Spent: 16 seconds 520 msec
# OK
# Time taken: 33.725 seconds

# %%
# %%hive
# SELECT * FROM persons;
# Out:
# SELECT * FROM persons;
# OK
# 10	Kylan	Sexton	1975-02-28 00:00:00	4	black
# 4	Roth	Fry	1975-01-29 00:00:00	1	black
# 15	Hope	Silva	1970-07-01 00:00:00	5	blue
# 7	Driscoll	Klein	1970-10-05 00:00:00	5	blue
# 5	Zoe	Conway	1974-07-03 00:00:00	2	blue
# 13	Vivian	Crane	1970-08-27 00:00:00	5	gray
# 12	Hope	Coffey	1973-12-24 00:00:00	5	green
# 1	Vivian	Hamilton	1971-07-08 00:00:00	1	green
# 17	Chanda	Boyer	1973-04-01 00:00:00	4	green
# 2	Karen	Holcomb	1974-05-23 00:00:00	4	green
# 9	Merritt	Guy	1974-10-17 00:00:00	4	indigo
# 11	Jordan	Estes	1969-12-07 00:00:00	4	indigo
# 3	Cody	Garrett	1973-04-22 00:00:00	1	orange
# 16	Ayanna	Jarvis	1974-02-11 00:00:00	5	orange
# 14	Clio	Noel	1972-12-12 00:00:00	5	red
# 8	Karyn	Diaz	1969-02-24 00:00:00	1	red
# 6	Gretchen	Kinney	1974-10-18 00:00:00	1	violet
# 18	Chadwick	Knight	1973-04-29 00:00:00	1	yellow
# Time taken: 0.405 seconds, Fetched: 18 row(s)

# %%
# !hdfs dfs -ls /tmp/hive-partitioned
# Out:
# Found 9 items
# drwxrwxrwx   - root supergroup          0 2019-11-27 21:44 /tmp/hive-partitioned/color=black
# drwxrwxrwx   - root supergroup          0 2019-11-27 21:45 /tmp/hive-partitioned/color=blue
# drwxrwxrwx   - root supergroup          0 2019-11-27 21:47 /tmp/hive-partitioned/color=gray
# drwxrwxrwx   - root supergroup          0 2019-11-27 21:43 /tmp/hive-partitioned/color=green
# drwxrwxrwx   - root supergroup          0 2019-11-27 21:47 /tmp/hive-partitioned/color=indigo
# drwxrwxrwx   - root supergroup          0 2019-11-27 21:45 /tmp/hive-partitioned/color=orange
# drwxrwxrwx   - root supergroup          0 2019-11-27 21:46 /tmp/hive-partitioned/color=red
# drwxrwxrwx   - root supergroup          0 2019-11-27 21:46 /tmp/hive-partitioned/color=violet
# drwxrwxrwx   - root supergroup          0 2019-11-27 21:48 /tmp/hive-partitioned/color=yellow

# %%
# !hdfs dfs -ls /tmp/hive-partitioned/color=black
# Out:
# Found 1 items
# drwxr-xr-x   - root supergroup          0 2019-11-27 21:44 /tmp/hive-partitioned/color=black/delta_0000002_0000002_0000

# %%
# !hdfs dfs -ls /tmp/hive-partitioned/color=black/delta_0000002_0000002_0000
# Out:
# Found 3 items
# -rw-r--r--   1 root supergroup        223 2019-11-27 21:44 /tmp/hive-partitioned/color=black/delta_0000002_0000002_0000/bucket_00000
# -rw-r--r--   1 root supergroup        929 2019-11-27 21:44 /tmp/hive-partitioned/color=black/delta_0000002_0000002_0000/bucket_00001
# -rw-r--r--   1 root supergroup        223 2019-11-27 21:44 /tmp/hive-partitioned/color=black/delta_0000002_0000002_0000/bucket_00002

# %%
## UPDATE

##   UPDATE tablename SET column = value [, column = value ...] [WHERE expression]

# %%
# %%hive
# UPDATE persons SET quantity = 100 WHERE color = 'red';
# Out:
# UPDATE persons SET quantity = 100 WHERE color = 'red';
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127215135_aa0c2f5d-406d-403b-a7ac-f77eda524726
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0026, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0026/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0026
# Hadoop job information for Stage-1: number of mappers: 3; number of reducers: 3
# 2019-11-27 21:51:45,926 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:51:53,931 Stage-1 map = 33%,  reduce = 0%, Cumulative CPU 3.04 sec
# 2019-11-27 21:51:54,985 Stage-1 map = 67%,  reduce = 0%, Cumulative CPU 5.62 sec
# 2019-11-27 21:51:57,238 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 9.25 sec
# 2019-11-27 21:52:02,896 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 11.38 sec
# 2019-11-27 21:52:03,970 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 13.29 sec
# 2019-11-27 21:52:05,032 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 16.56 sec
# MapReduce Total cumulative CPU time: 16 seconds 560 msec
# Ended Job = job_1574885052112_0026
# Loading data to table demo.persons partition (color=null)
#
#
# 	 Time taken to load dynamic partitions: 0.316 seconds
# 	 Time taken for adding to write entity : 0.001 seconds
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 3  Reduce: 3   Cumulative CPU: 16.56 sec   HDFS Read: 33126 HDFS Write: 1056 SUCCESS
# Total MapReduce CPU Time Spent: 16 seconds 560 msec
# OK
# Time taken: 31.336 seconds

# %%
# %%hive
# SELECT * FROM persons;
# Out:
# SELECT * FROM persons;
# OK
# 10	Kylan	Sexton	1975-02-28 00:00:00	4	black
# 4	Roth	Fry	1975-01-29 00:00:00	1	black
# 15	Hope	Silva	1970-07-01 00:00:00	5	blue
# 7	Driscoll	Klein	1970-10-05 00:00:00	5	blue
# 5	Zoe	Conway	1974-07-03 00:00:00	2	blue
# 13	Vivian	Crane	1970-08-27 00:00:00	5	gray
# 12	Hope	Coffey	1973-12-24 00:00:00	5	green
# 1	Vivian	Hamilton	1971-07-08 00:00:00	1	green
# 17	Chanda	Boyer	1973-04-01 00:00:00	4	green
# 2	Karen	Holcomb	1974-05-23 00:00:00	4	green
# 9	Merritt	Guy	1974-10-17 00:00:00	4	indigo
# 11	Jordan	Estes	1969-12-07 00:00:00	4	indigo
# 3	Cody	Garrett	1973-04-22 00:00:00	1	orange
# 16	Ayanna	Jarvis	1974-02-11 00:00:00	5	orange
# 14	Clio	Noel	1972-12-12 00:00:00	100	red
# 8	Karyn	Diaz	1969-02-24 00:00:00	100	red
# 6	Gretchen	Kinney	1974-10-18 00:00:00	1	violet
# 18	Chadwick	Knight	1973-04-29 00:00:00	1	yellow
# Time taken: 0.314 seconds, Fetched: 18 row(s)

# %%
## DELETE

##   DELETE FROM tablename [WHERE expression]

# %%
# %%hive
# DELETE FROM persons WHERE id = 10;
# Out:
# DELETE FROM persons WHERE id = 10;
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127215220_2a89d834-d563-45b6-86bc-4a4a72c3244e
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 3
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0027, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0027/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0027
# Hadoop job information for Stage-1: number of mappers: 27; number of reducers: 3
# 2019-11-27 21:52:30,844 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:52:44,064 Stage-1 map = 4%,  reduce = 0%, Cumulative CPU 5.02 sec
# 2019-11-27 21:52:47,729 Stage-1 map = 7%,  reduce = 0%, Cumulative CPU 9.41 sec
# 2019-11-27 21:52:50,202 Stage-1 map = 11%,  reduce = 0%, Cumulative CPU 13.99 sec
# 2019-11-27 21:52:51,346 Stage-1 map = 15%,  reduce = 0%, Cumulative CPU 17.92 sec
# 2019-11-27 21:52:53,645 Stage-1 map = 19%,  reduce = 0%, Cumulative CPU 21.85 sec
# 2019-11-27 21:52:55,999 Stage-1 map = 22%,  reduce = 0%, Cumulative CPU 25.72 sec
# 2019-11-27 21:53:01,194 Stage-1 map = 26%,  reduce = 0%, Cumulative CPU 29.8 sec
# 2019-11-27 21:53:05,863 Stage-1 map = 30%,  reduce = 0%, Cumulative CPU 33.75 sec
# 2019-11-27 21:53:08,152 Stage-1 map = 37%,  reduce = 0%, Cumulative CPU 42.27 sec
# 2019-11-27 21:53:09,376 Stage-1 map = 41%,  reduce = 0%, Cumulative CPU 46.44 sec
# 2019-11-27 21:53:16,394 Stage-1 map = 44%,  reduce = 0%, Cumulative CPU 50.09 sec
# 2019-11-27 21:53:18,639 Stage-1 map = 44%,  reduce = 5%, Cumulative CPU 50.48 sec
# 2019-11-27 21:53:19,850 Stage-1 map = 48%,  reduce = 5%, Cumulative CPU 54.52 sec
# 2019-11-27 21:53:22,139 Stage-1 map = 56%,  reduce = 5%, Cumulative CPU 62.88 sec
# 2019-11-27 21:53:24,339 Stage-1 map = 56%,  reduce = 6%, Cumulative CPU 62.99 sec
# 2019-11-27 21:53:28,994 Stage-1 map = 59%,  reduce = 6%, Cumulative CPU 67.09 sec
# 2019-11-27 21:53:31,233 Stage-1 map = 63%,  reduce = 7%, Cumulative CPU 70.92 sec
# 2019-11-27 21:53:32,400 Stage-1 map = 63%,  reduce = 14%, Cumulative CPU 71.28 sec
# 2019-11-27 21:53:33,535 Stage-1 map = 67%,  reduce = 14%, Cumulative CPU 75.64 sec
# 2019-11-27 21:53:34,664 Stage-1 map = 70%,  reduce = 14%, Cumulative CPU 79.72 sec
# 2019-11-27 21:53:36,928 Stage-1 map = 70%,  reduce = 15%, Cumulative CPU 79.81 sec
# 2019-11-27 21:53:38,087 Stage-1 map = 70%,  reduce = 16%, Cumulative CPU 79.92 sec
# 2019-11-27 21:53:40,309 Stage-1 map = 74%,  reduce = 16%, Cumulative CPU 83.41 sec
# 2019-11-27 21:53:42,525 Stage-1 map = 78%,  reduce = 16%, Cumulative CPU 86.94 sec
# 2019-11-27 21:53:43,594 Stage-1 map = 81%,  reduce = 16%, Cumulative CPU 90.69 sec
# 2019-11-27 21:53:44,679 Stage-1 map = 81%,  reduce = 17%, Cumulative CPU 90.77 sec
# 2019-11-27 21:53:48,002 Stage-1 map = 81%,  reduce = 26%, Cumulative CPU 91.06 sec
# 2019-11-27 21:53:49,115 Stage-1 map = 81%,  reduce = 27%, Cumulative CPU 91.1 sec
# 2019-11-27 21:53:50,229 Stage-1 map = 85%,  reduce = 27%, Cumulative CPU 94.53 sec
# 2019-11-27 21:53:51,297 Stage-1 map = 93%,  reduce = 27%, Cumulative CPU 102.51 sec
# 2019-11-27 21:53:53,477 Stage-1 map = 93%,  reduce = 28%, Cumulative CPU 102.64 sec
# 2019-11-27 21:53:54,588 Stage-1 map = 93%,  reduce = 30%, Cumulative CPU 102.71 sec
# 2019-11-27 21:53:55,702 Stage-1 map = 93%,  reduce = 31%, Cumulative CPU 102.79 sec
# 2019-11-27 21:53:56,776 Stage-1 map = 96%,  reduce = 31%, Cumulative CPU 107.25 sec
# 2019-11-27 21:53:57,865 Stage-1 map = 100%,  reduce = 31%, Cumulative CPU 111.38 sec
# 2019-11-27 21:54:00,136 Stage-1 map = 100%,  reduce = 77%, Cumulative CPU 117.47 sec
# 2019-11-27 21:54:01,192 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 119.19 sec
# MapReduce Total cumulative CPU time: 1 minutes 59 seconds 190 msec
# Ended Job = job_1574885052112_0027
# Loading data to table demo.persons partition (color=null)
#
#
# 	 Time taken to load dynamic partitions: 0.199 seconds
# 	 Time taken for adding to write entity : 0.0 seconds
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 27  Reduce: 3   Cumulative CPU: 119.19 sec   HDFS Read: 215526 HDFS Write: 602 SUCCESS
# Total MapReduce CPU Time Spent: 1 minutes 59 seconds 190 msec
# OK
# Time taken: 103.688 seconds

# %%
# %%hive
# SELECT * FROM persons ORDER BY id;
# Out:
# SELECT * FROM persons ORDER BY id;
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20191127215632_4ecc55af-2986-4594-bb26-072aec786f98
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1574885052112_0028, Tracking URL = http://499bf3956267:8088/proxy/application_1574885052112_0028/
# Kill Command = /usr/local/hadoop/bin/hadoop job  -kill job_1574885052112_0028
# Hadoop job information for Stage-1: number of mappers: 27; number of reducers: 1
# 2019-11-27 21:56:38,467 Stage-1 map = 0%,  reduce = 0%
# 2019-11-27 21:56:43,798 Stage-1 map = 4%,  reduce = 0%, Cumulative CPU 1.67 sec
# 2019-11-27 21:56:46,036 Stage-1 map = 7%,  reduce = 0%, Cumulative CPU 3.16 sec
# 2019-11-27 21:56:48,316 Stage-1 map = 11%,  reduce = 0%, Cumulative CPU 5.34 sec
# 2019-11-27 21:56:50,669 Stage-1 map = 15%,  reduce = 0%, Cumulative CPU 7.37 sec
# 2019-11-27 21:56:52,974 Stage-1 map = 19%,  reduce = 0%, Cumulative CPU 9.33 sec
# 2019-11-27 21:56:54,129 Stage-1 map = 22%,  reduce = 0%, Cumulative CPU 11.12 sec
# 2019-11-27 21:56:55,209 Stage-1 map = 26%,  reduce = 0%, Cumulative CPU 12.58 sec
# 2019-11-27 21:56:57,428 Stage-1 map = 33%,  reduce = 0%, Cumulative CPU 15.71 sec
# 2019-11-27 21:57:02,150 Stage-1 map = 37%,  reduce = 0%, Cumulative CPU 17.28 sec
# 2019-11-27 21:57:03,635 Stage-1 map = 41%,  reduce = 0%, Cumulative CPU 19.55 sec
# 2019-11-27 21:57:04,734 Stage-1 map = 48%,  reduce = 0%, Cumulative CPU 22.28 sec
# 2019-11-27 21:57:05,813 Stage-1 map = 52%,  reduce = 0%, Cumulative CPU 23.97 sec
# 2019-11-27 21:57:11,602 Stage-1 map = 59%,  reduce = 0%, Cumulative CPU 28.0 sec
# 2019-11-27 21:57:13,925 Stage-1 map = 63%,  reduce = 20%, Cumulative CPU 29.97 sec
# 2019-11-27 21:57:14,984 Stage-1 map = 70%,  reduce = 20%, Cumulative CPU 34.65 sec
# 2019-11-27 21:57:20,817 Stage-1 map = 74%,  reduce = 23%, Cumulative CPU 36.43 sec
# 2019-11-27 21:57:21,959 Stage-1 map = 78%,  reduce = 23%, Cumulative CPU 38.41 sec
# 2019-11-27 21:57:23,017 Stage-1 map = 81%,  reduce = 23%, Cumulative CPU 40.59 sec
# 2019-11-27 21:57:24,138 Stage-1 map = 85%,  reduce = 23%, Cumulative CPU 42.34 sec
# 2019-11-27 21:57:25,238 Stage-1 map = 89%,  reduce = 23%, Cumulative CPU 44.26 sec
# 2019-11-27 21:57:26,339 Stage-1 map = 89%,  reduce = 30%, Cumulative CPU 44.32 sec
# 2019-11-27 21:57:28,513 Stage-1 map = 96%,  reduce = 30%, Cumulative CPU 48.23 sec
# 2019-11-27 21:57:29,562 Stage-1 map = 100%,  reduce = 30%, Cumulative CPU 49.45 sec
# 2019-11-27 21:57:30,610 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 50.6 sec
# MapReduce Total cumulative CPU time: 50 seconds 600 msec
# Ended Job = job_1574885052112_0028
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 27  Reduce: 1   Cumulative CPU: 50.6 sec   HDFS Read: 201083 HDFS Write: 1030 SUCCESS
# Total MapReduce CPU Time Spent: 50 seconds 600 msec
# OK
# 1	Vivian	Hamilton	1971-07-08 00:00:00	1	green
# 2	Karen	Holcomb	1974-05-23 00:00:00	4	green
# 3	Cody	Garrett	1973-04-22 00:00:00	1	orange
# 4	Roth	Fry	1975-01-29 00:00:00	1	black
# 5	Zoe	Conway	1974-07-03 00:00:00	2	blue
# 6	Gretchen	Kinney	1974-10-18 00:00:00	1	violet
# 7	Driscoll	Klein	1970-10-05 00:00:00	5	blue
# 8	Karyn	Diaz	1969-02-24 00:00:00	100	red
# 9	Merritt	Guy	1974-10-17 00:00:00	4	indigo
# 11	Jordan	Estes	1969-12-07 00:00:00	4	indigo
# 12	Hope	Coffey	1973-12-24 00:00:00	5	green
# 13	Vivian	Crane	1970-08-27 00:00:00	5	gray
# 14	Clio	Noel	1972-12-12 00:00:00	100	red
# 15	Hope	Silva	1970-07-01 00:00:00	5	blue
# 16	Ayanna	Jarvis	1974-02-11 00:00:00	5	orange
# 17	Chanda	Boyer	1973-04-01 00:00:00	4	green
# 18	Chadwick	Knight	1973-04-29 00:00:00	1	yellow
# Time taken: 59.03 seconds, Fetched: 17 row(s)

# %%
## MERGE

##   MERGE INTO <target table> AS T USING <source expression/table> AS S
##   ON <boolean expression1>
##   WHEN MATCHED [AND <boolean expression2>] THEN UPDATE SET <set clause list>
##   WHEN MATCHED [AND <boolean expression3>] THEN DELETE
##   WHEN NOT MATCHED [AND <boolean expression4>] THEN INSERT VALUES<value list>

# %%
# %%hive
# -- limpia la base de datos
# DROP DATABASE IF EXISTS demo CASCADE;
# Out:
# -- limpia la base de datos
# DROP DATABASE IF EXISTS demo CASCADE;
# OK
# Time taken: 0.558 seconds

# %%
# !rm *.log
# Out:
# rm: cannot remove 'derby.log': Text file busy
# rm: cannot remove 'ubuntu-bionic-18.04-cloudimg-console.log': Text file busy
